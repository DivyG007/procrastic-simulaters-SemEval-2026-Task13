# %%
# !git clone https://github.com/DivyG007/procrastic-simulaters-SemEval-2026-Task13.git

# %cd procrastic-simulaters-SemEval-2026-Task13/Improved_Models/task_A/final_model

# !python3 ensemble.py
# Out:
# Cloning into 'procrastic-simulaters-SemEval-2026-Task13'...
# remote: Enumerating objects: 310, done.
# remote: Counting objects: 100% (229/229), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 310 (delta 132), reused 175 (delta 84), pack-reused 81 (from 1)
# Receiving objects: 100% (310/310), 13.60 MiB | 29.83 MiB/s, done.
# Resolving deltas: 100% (151/151), done.
# /kaggle/working/procrastic-simulaters-SemEval-2026-Task13/Improved_Models/task_A/final_model
# 17:27:02 | INFO | ======================================================================
# 17:27:02 | INFO |   TASK A — ENSEMBLE PIPELINE
# 17:27:02 | INFO | ======================================================================
# 17:27:02 | INFO |   Strategy:       soft_vote
# 17:27:02 | INFO |   Skip training:  False
# 17:27:02 | INFO |   Cache dir:      /kaggle/working/ensemble_cache
# 17:27:02 | INFO |   Output CSV:     /kaggle/working/ensemble_submission.csv
# ...
